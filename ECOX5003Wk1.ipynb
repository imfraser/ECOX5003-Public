# %%
import numpy as np
import pandas as pd
from statsmodels.formula.api import ols
import matplotlib as plt

# %%
df = pd.read_csv('/Wage.csv')
df.head()
df.describe()
# Out:
#              wage        educ      exper      female      tenure
# count  526.000000  526.000000  526.00000  526.000000  526.000000
# mean     5.896103   12.562738   17.01711    0.479087    5.104563
# std      3.693086    2.769022   13.57216    0.500038    7.224462
# min      0.530000    0.000000    1.00000    0.000000    0.000000
# 25%      3.330000   12.000000    5.00000    0.000000    0.000000
# 50%      4.650000   12.000000   13.50000    0.000000    2.000000
# 75%      6.880000   14.000000   26.00000    1.000000    7.000000
# max     24.980000   18.000000   51.00000    1.000000   44.000000

# %%
plt.rcParams['figure.figsize'] = [10, 5]
df['educ'].plot(kind='hist',y='educ',bins=20,title='Educ',grid=True)
# Out:
# <Axes: title={'center': 'Educ'}, ylabel='Frequency'>

# %% [markdown]
# # New Section
