# %%
import pandas as pd
from statsmodels.formula.api import ols
from statsmodels.formula.api import glm
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [10, 5]

# %%
import openpyxl
import seaborn as sns
import statsmodels.stats.diagnostic as dg
import statsmodels.api as sm
import statsmodels.stats.api as sms
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.compat import lzip

# %%
df = pd.read_csv('/content/UK Wage Data.csv')
df.head()
df.describe()
# Out:
#               Wage          Age       Gender       Degree      OtherHE  \
# count  3391.000000  3391.000000  3391.000000  3391.000000  3391.000000
# mean   1736.141603    37.779416     0.407549     0.223533     0.322324
# std     923.529353    11.455918     0.491451     0.416674     0.467435
# min     360.277130    16.000000     0.000000     0.000000     0.000000
# 25%    1086.836060    28.000000     0.000000     0.000000     0.000000
# 50%    1501.154785    37.000000     0.000000     0.000000     0.000000
# 75%    2109.622803    47.000000     1.000000     0.000000     1.000000
# max    6705.157715    64.000000     1.000000     1.000000     1.000000
#
#            ALevels      OLevels          CSE        Vocat
# count  3391.000000  3391.000000  3391.000000  3391.000000
# mean      0.135948     0.179003     0.037157     0.034798
# std       0.342784     0.383412     0.189175     0.183295
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
df['Lwage']=np.log(df['Wage'])

# %%
df.head()
df.describe()
# Out:
#               Wage          Age       Gender       Degree      OtherHE  \
# count  3391.000000  3391.000000  3391.000000  3391.000000  3391.000000
# mean   1736.141603    37.779416     0.407549     0.223533     0.322324
# std     923.529353    11.455918     0.491451     0.416674     0.467435
# min     360.277130    16.000000     0.000000     0.000000     0.000000
# 25%    1086.836060    28.000000     0.000000     0.000000     0.000000
# 50%    1501.154785    37.000000     0.000000     0.000000     0.000000
# 75%    2109.622803    47.000000     1.000000     0.000000     1.000000
# max    6705.157715    64.000000     1.000000     1.000000     1.000000
#
#            ALevels      OLevels          CSE        Vocat        Lwage
# count  3391.000000  3391.000000  3391.000000  3391.000000  3391.000000
# mean      0.135948     0.179003     0.037157     0.034798     7.337712
# std       0.342784     0.383412     0.189175     0.183295     0.488090
# ...

# %%
mod=ols('Lwage~Age+Degree+OtherHE+ALevels+OLevels+CSE+Vocat+Gender',data=df).fit()
print(mod.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Lwage   R-squared:                       0.272
# Model:                            OLS   Adj. R-squared:                  0.270
# Method:                 Least Squares   F-statistic:                     157.6
# Date:                Fri, 09 May 2025   Prob (F-statistic):          3.56e-226
# Time:                        05:44:58   Log-Likelihood:                -1841.8
# No. Observations:                3391   AIC:                             3702.
# Df Residuals:                    3382   BIC:                             3757.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.7185      0.042    161.007      0.000       6.637       6.800
# ...

# %%
df['Age2']=(df['Age']*df['Age'])

# %%
df.head()
df.describe()
# Out:
#               Wage          Age       Gender       Degree      OtherHE  \
# count  3391.000000  3391.000000  3391.000000  3391.000000  3391.000000
# mean   1736.141603    37.779416     0.407549     0.223533     0.322324
# std     923.529353    11.455918     0.491451     0.416674     0.467435
# min     360.277130    16.000000     0.000000     0.000000     0.000000
# 25%    1086.836060    28.000000     0.000000     0.000000     0.000000
# 50%    1501.154785    37.000000     0.000000     0.000000     0.000000
# 75%    2109.622803    47.000000     1.000000     0.000000     1.000000
# max    6705.157715    64.000000     1.000000     1.000000     1.000000
#
#            ALevels      OLevels          CSE        Vocat        Lwage  \
# count  3391.000000  3391.000000  3391.000000  3391.000000  3391.000000
# mean      0.135948     0.179003     0.037157     0.034798     7.337712
# std       0.342784     0.383412     0.189175     0.183295     0.488090
# ...

# %%
# !pip install openpyxl
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import openpyxl
import seaborn as sns
import statsmodels.stats.diagnostic as dg
import statsmodels.api as sm
import statsmodels.stats.api as sms
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.compat import lzip

# %%
Parta = df.iloc[0:2009,:]
Partb = df.iloc[2009:,:]
Parta
Partb
# Out:
#              Wage  Age  Gender  Degree  OtherHE  ALevels  OLevels  CSE  Vocat  \
# 2009  1000.769836   23       1       1        0        0        0    0      0
# 2010   975.000000   49       1       0        0        0        0    0      1
# 2011  1916.666626   34       1       0        1        0        0    0      0
# 2012  1901.462646   57       1       0        0        0        1    0      0
# 2013  1625.000000   24       1       1        0        0        0    0      0
# ...           ...  ...     ...     ...      ...      ...      ...  ...    ...
# 3386   758.333313   23       1       1        0        0        0    0      0
# 3387  2244.726807   23       1       1        0        0        0    0      0
# 3388   912.938843   18       1       0        0        1        0    0      0
# 3389  1200.923828   40       1       0        0        0        1    0      0
# 3390   905.696716   19       1       0        0        0        1    0      0
#
#          Lwage  Age2
# ...

# %%
w='Lwage~Age+Age2+Degree+OtherHE+ALevels+OLevels+CSE+Vocat+Gender'

# %%
mod=ols('Lwage~Age+Age2+Degree+OtherHE+ALevels+OLevels+CSE+Vocat',data=df).fit()
print(mod.summary())
RSSd = mod.ssr
RSSd
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Lwage   R-squared:                       0.258
# Model:                            OLS   Adj. R-squared:                  0.257
# Method:                 Least Squares   F-statistic:                     147.3
# Date:                Fri, 09 May 2025   Prob (F-statistic):          3.97e-213
# Time:                        07:23:45   Log-Likelihood:                -1872.0
# No. Observations:                3391   AIC:                             3762.
# Df Residuals:                    3382   BIC:                             3817.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.4077      0.084     64.416      0.000       5.243       5.572
# ...

# %%
moda=ols('Lwage~Age+Age2+Degree+OtherHE+ALevels+OLevels+CSE+Vocat',data=Parta).fit()
RSSb = moda.ssr
RSSb
# Out:
# np.float64(312.51831582056576)

# %%
modb=ols('Lwage~Age+Age2+Degree+OtherHE+ALevels+OLevels+CSE+Vocat',data=Partb).fit()
RSSnb = modb.ssr
RSSnb
# Out:
# np.float64(223.1181940500946)

# %%
chow = ((RSSd-(RSSb+RSSnb))/9)/((RSSb+RSSnb)/(3391-2*8))
chow
# Out:
# np.float64(44.30290026929885)

# %% [markdown]
# This the test stat shown in the week 5 worksheet. There is a command to run the chow test but it won't seem to load properly, so have done it this way which is rather tedious...next up the RESET test - will use same data set and simply show how to implement.

# %%
pip install statsmodels
import statsmodels.api as sm

# %%
mod=ols('Lwage~Age+Age2+Degree+OtherHE+ALevels+OLevels+CSE+Vocat',data=df).fit()
print(mod.summary())
#Get the residuals from the model fit
res=mod.resid
#Import the required module for the linear_reset function
import statsmodels.stats.diagnostic as dg # import the diagnostic module for linear_reset
# Use dg to call linear_reset, since dg is now an alias for statsmodels.stats.diagnostic
dg.linear_reset(res, power=3, test_type='fitted', use_f=False, cov_type='nonrobust')
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Lwage   R-squared:                       0.258
# Model:                            OLS   Adj. R-squared:                  0.257
# Method:                 Least Squares   F-statistic:                     147.3
# Date:                Fri, 09 May 2025   Prob (F-statistic):          3.97e-213
# Time:                        07:45:29   Log-Likelihood:                -1872.0
# No. Observations:                3391   AIC:                             3762.
# Df Residuals:                    3382   BIC:                             3817.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.4077      0.084     64.416      0.000       5.243       5.572
# ...
